# %% [markdown]
# # Primer design Solution

# %%
import os


restriction_sites = {"EcoR1": "GAATTC",
                    "HindIII": "AAGCTT",
                    "BamHI": "GGATCC",
                    "XhoI": "CTCGAG",
                    "XbaI": "TCTAGA",
                    "PstI": "CTGCAG"}


def rev_comp(seq):
    bases = {"A": "T", "C": "G", "T": "A", "G": "C"}
    return "".join([bases[i] for i in seq])[::-1]


def generate_primer(entry):
    f_primer = entry["seq"][:20]
    r_primer = entry["seq"][-20:]
    r_primer = rev_comp(r_primer)
    rs1 = entry["rs"][0] 
    rs2 = entry["rs"][1] 
    f_primer = restriction_sites[rs1] + f_primer
    r_primer = restriction_sites[rs2] + r_primer
    return f_primer, r_primer
    


def read_file(filepath):
    with open(filepath) as f:
        entry = {}
        seq = []
        for line in f:
            if line.startswith(">"):
                line = line.strip().split("_")
                rs = [i.split(":")[-1] for i in line]
        else:
            seq.append(line.strip())
    entry.update({"seq": "".join(seq), "rs": rs})
    return entry


def main():
    folder = "files"
    out_file = "answers.csv"
    num_of_files = 0
    for filename in os.listdir(folder):
        if filename.endswith(".fasta"):
            num_of_files += 1
    answer_list = []
    for filenum in range(num_of_files):
        filepath = os.path.join("files", str(filenum + 1) + ".fasta")
        entry = read_file(filepath)
        primers = generate_primer(entry)
        answer_list.append(primers)
        print(filepath, primers)
 
    with open(out_file, "w") as f:
        for i in answer_list:
            write_str = "{};{}\n".format(i[0], i[1])
            f.write(write_str)
    print("done")
    
main()
# Out:
# files\1.fasta ('TCTAGAATGATCGCCGCGACCCAGAT', 'GAATTCCTATGGTTGGCTTTCGACGT')
# files\2.fasta ('GGATCCATGTTAGAAGATTGGGTTAT', 'GAATTCTCACGGTTTCGAGCGTATCG')
# files\3.fasta ('TCTAGAATGAATGGTTGTTCGGTCGC', 'GGATCCTCAAAAAACACGGGTCTTAT')
# files\4.fasta ('TCTAGAATGCGTTGTAGAAAGGGTCG', 'CTGCAGTCAGGAGAGTATTTTGTGAG')
# files\5.fasta ('GGATCCATGAAGCTGCGTGGGCGATC', 'CTGCAGCTAATTGCACTTGATGAGCT')
# files\6.fasta ('AAGCTTATGCATGCTCTGAACAGATC', 'GAATTCCTAATCAACCGAGACAATGG')
# files\7.fasta ('GAATTCATGAGCACTAATGGTATAGG', 'CTGCAGTCAGACGTCTGACGGCCACA')
# files\8.fasta ('GGATCCATGATAACCTACGTTCATCG', 'CTGCAGTCATAGTATCCACCTTGATA')
# files\9.fasta ('CTGCAGATGCCAGTAGTACATCCCTT', 'TCTAGACTACACTGCAAACAGTTTAC')
# files\10.fasta ('CTGCAGATGCTTTGTGTCGATCCGGG', 'TCTAGATCACGGGGTTAATGCGCTAT')
# files\11.fasta ('CTCGAGATGGACGAAACTGAAAAGTC', 'CTGCAGTTAACTCAAGTACAGTCTCC')
# files\12.fasta ('CTCGAGATGATTGTGCCGCTCCGGGC', 'GGATCCCTACCTCGTTCCCGAACCCA')
# files\13.fasta ('GAATTCATGTATTGGGTAAAAAGTCC', 'AAGCTTTTACAGTTGGCCCAGTGCTG')
# files\14.fasta ('GAATTCATGTCAGTCCTAAAGGGTCC', 'TCTAGATCATCTGAGCATTGGGTAAA')
# files\15.fasta ('GAATTCATGTCTAATCTGATAGACCA', 'GGATCCTTATTGTTCCACCTCTTCCG')
# files\16.fasta ('GAATTCATGGATTCTTTTTCCTGTCT', 'GGATCCTCAACGGGTCGGAAGTACCC')
# files\17.fasta ('TCTAGAATGGAAGATGTCATATTTAA', 'GGATCCTTACATATCAGCGTTTCGGG')
# files\18.fasta ('TCTAGAATGATTACAAAACCCGTACT', 'AAGCTTTCAATTGCTTTGAGAAGTCG')
# files\19.fasta ('AAGCTTATGATTCCTGTATGTCGGGT', 'TCTAGATCACTCAGCCGCCAACATGC')
# files\20.fasta ('AAGCTTATGTTCTCATCCGGTATACC', 'TCTAGATTATTCCGCGTGTCGATGGA')
# files\21.fasta ('GGATCCATGTTATTTCGTCCACTCAG', 'TCTAGATTAACCGCGGATACGTGCCC')
# files\22.fasta ('TCTAGAATGGGGAAGCACTGTCAAAG', 'AAGCTTTCACCTTCGACCTGTTACTT')
# files\23.fasta ('CTCGAGATGCTAGGCCCAACCAGACC', 'CTGCAGTTAGCCCCGTCCACGCACTA')
# files\24.fasta ('AAGCTTATGATACATACTCTACGTAA', 'GGATCCTCATCGGATTTCTCTAATGG')
# files\25.fasta ('CTGCAGATGCGTCATATTCTTTTAGA', 'CTCGAGTCAGCAGCTATGACAGGCCA')
# files\26.fasta ('GGATCCATGGGGCGACATACTATTGC', 'CTGCAGTCATGCCGAATGCGTCATGC')
# files\27.fasta ('GGATCCATGTTCCCCTGCCACGGTTG', 'CTCGAGTTATATGTCGGCATGGCTGC')
# files\28.fasta ('GGATCCATGGGGCAGTATAGTTCCGT', 'CTGCAGCTACATGCAAAGTTGAAATT')
# files\29.fasta ('GGATCCATGCCAGGGCATAAAGTCAG', 'TCTAGATCAATACGGGTTGCTGGCGC')
# files\30.fasta ('CTGCAGATGATTAGCCCCGTTTCTCC', 'GAATTCCTAGTGAATGCCTACGCGTA')
# files\31.fasta ('GAATTCATGTCGGTCGTTCAAGTCAC', 'TCTAGATTAGTGGTACAAGTGGACCC')
# files\32.fasta ('CTGCAGATGGCGATACAAGTCCGTCC', 'TCTAGATCACATACCCGTCACAGAAG')
# files\33.fasta ('AAGCTTATGTACTCCGCGAGGACAAC', 'GAATTCTCATCTAGGGTTACGGTTCA')
# files\34.fasta ('CTCGAGATGGTGTGTACAAGTCAGTG', 'GGATCCTTAAAGTAGCGACTCCTTAC')
# files\35.fasta ('CTCGAGATGAGTCCAGAGGGTAGACA', 'AAGCTTTCATGACGGGGGTCCGCTGA')
# files\36.fasta ('AAGCTTATGATAGTTAAGAACCAGGG', 'CTCGAGTCAGCCCATACAGCATACAT')
# files\37.fasta ('AAGCTTATGTCGTCTCCTGCGACAGT', 'CTGCAGTCATTTCACCCCTGCCAACC')
# files\38.fasta ('GAATTCATGTTGGTCACAGGACCGAG', 'CTCGAGCTAACAAATTCGTTTTTTCT')
# files\39.fasta ('GGATCCATGGGCCGACAGTGCCAATG', 'CTGCAGTCACCTGCAAACAGGCCATA')
# files\40.fasta ('CTGCAGATGCGTCTTCACCTTTGCTG', 'AAGCTTCTAGGGGTGACTCTTCCTAG')
# files\41.fasta ('GGATCCATGGCGTTGTTGATCCAGCG', 'TCTAGACTAATATGATAGCATATCGG')
# files\42.fasta ('GGATCCATGGACCCCGAACGGTCTGC', 'CTCGAGTCAGTTGTACGCGAACCTCC')
# files\43.fasta ('CTCGAGATGCAGTATTTTGGATGCAC', 'AAGCTTTTAGAGCATCCACAGACCGT')
# files\44.fasta ('AAGCTTATGAAGCACCTGTGGTCGGT', 'GAATTCTTACCGCCGCACTCGGAACC')
# files\45.fasta ('GAATTCATGTTGTCGGGATTAGGCAT', 'AAGCTTTCAATTTCTACAGAGGAATG')
# files\46.fasta ('GAATTCATGTCGGCAAATTCGCGCCG', 'CTCGAGTCAACGCAGCCTTAATGTCT')
# files\47.fasta ('GGATCCATGGGTCTCACGCAGCCAAC', 'TCTAGATCATGACAGAACTGAATAAC')
# files\48.fasta ('AAGCTTATGCCGCACCAAGATGAACG', 'GAATTCTCAAAGTGCAGCGCATAACG')
# files\49.fasta ('CTGCAGATGACGAACTTACACAGTCC', 'CTCGAGCTATGGACTACGGTCTTCGA')
# files\50.fasta ('CTCGAGATGAGCGTTTGCCTCAGCTC', 'GGATCCTCACGTGACGCGTGAAATTA')
# files\51.fasta ('CTGCAGATGACGGCATGGCAATATGG', 'CTCGAGTTAGCAATGATAACCTTTCC')
# files\52.fasta ('TCTAGAATGGTCCTGACTTTGGCGTG', 'GGATCCTTACGCGGTTTTCCGTAAAA')
# files\53.fasta ('CTCGAGATGATCGGGCATAGAGAAAC', 'GGATCCTCAGAGTAAATACGCGTACT')
# files\54.fasta ('GGATCCATGGTTAGTAGAGTGACGCT', 'CTCGAGTCACAATACGGTTAGGACCC')
# files\55.fasta ('CTCGAGATGAGGACGCCTCAGACAGA', 'TCTAGACTACGTCTTGGGAACGTTTT')
# files\56.fasta ('GGATCCATGGTTGAACTTGTAACGTT', 'AAGCTTTTAACATGTTCCTATGCCTC')
# files\57.fasta ('CTGCAGATGATAACGATTATCCCTAA', 'CTCGAGTTAGGATTCGAGACACGAAA')
# files\58.fasta ('TCTAGAATGATATCCCCGAAGAGTGT', 'GAATTCTCAATCCCCCCAGCGTGTCT')
# files\59.fasta ('AAGCTTATGGGGAACTTGAGGAAGAT', 'CTGCAGCTACCTGAACCCCCCAGCGG')
# files\60.fasta ('CTCGAGATGCCAGTGAAAACAGGGGA', 'TCTAGATTAAATACGCAAACATTTGA')
# files\61.fasta ('GAATTCATGGCCCGAGCTCAATCGAT', 'TCTAGACTATGACTTTTTGTTACCAG')
# files\62.fasta ('TCTAGAATGAAGTCTGATGGCCGTAA', 'AAGCTTTCAGGTGGATAACCAACAGT')
# files\63.fasta ('TCTAGAATGGGACGAGAAAGTTGCAA', 'CTGCAGTCATAAACCCAGCCCTTTTA')
# files\64.fasta ('CTCGAGATGAGGATCTACTGCTGTAC', 'AAGCTTTCACTGACACGTTCTCTCTT')
# files\65.fasta ('GAATTCATGCTTTGGTTTCACGGTGA', 'CTGCAGTCATTCGAGTCTGCGCGTGT')
# files\66.fasta ('CTCGAGATGCGAAACTTATACGCAAG', 'GAATTCTTATTCCTCTTCGCTAACTC')
# files\67.fasta ('AAGCTTATGCCGTGTCGCTTAGGCCC', 'GGATCCCTAGTATGGCGAGGGTCTTC')
# files\68.fasta ('CTCGAGATGCGATACATTGTTGATCG', 'AAGCTTCTACGGCAGCAATTTCCGCC')
# files\69.fasta ('CTGCAGATGGCGTTGGAGAAGTTCTG', 'AAGCTTCTATTTTGGGTCCACATGAC')
# files\70.fasta ('AAGCTTATGCGGGAGGTTCCATCTAA', 'CTGCAGTCAGCCTATCCCGCGGTCTC')
# files\71.fasta ('TCTAGAATGAATACGCCGGGTGAGCC', 'CTCGAGTTAGTGTGCCTGTGCTAGGA')
# files\72.fasta ('AAGCTTATGGTCACATGGACGCAAAT', 'GGATCCCTAATTCAAGCGTTTTCCTA')
# files\73.fasta ('GGATCCATGACGGCCCCGTCTGGTAA', 'CTCGAGTTATCGCCTGCGTGTACAGA')
# files\74.fasta ('CTGCAGATGTCCTTCTGGTATGAATT', 'TCTAGATCAACTACCCGGAATCAAGG')
# files\75.fasta ('TCTAGAATGCTTCGCGGCTCCGTCCT', 'GAATTCCTATTCGGTAGGAGACCGTA')
# files\76.fasta ('GGATCCATGAAAGTACACAGAGGTAC', 'CTCGAGTTAGGAGTTCGCTCTTCCAC')
# files\77.fasta ('CTCGAGATGGAAATAACTTCAGCTGC', 'TCTAGATTATTCCGCGCTGACAATTT')
# files\78.fasta ('AAGCTTATGGCGCAGGCCCTGGCGCA', 'GGATCCTCACTCACGCAGAGGGGCGA')
# files\79.fasta ('TCTAGAATGTTCACCTACCACCATGT', 'GAATTCTTATAGGCTTTTTAGGGAAG')
# files\80.fasta ('GGATCCATGGACTTCTGTTCGCGTGG', 'AAGCTTTCACAGGATGAGCATACAAA')
# files\81.fasta ('TCTAGAATGGATAATAATCAGGTATG', 'GAATTCTCATTCACTATTACGAACGC')
# files\82.fasta ('GAATTCATGCTAGTCATTCCAGGTAG', 'GGATCCTCATTGACAAAGACGTTCAA')
# files\83.fasta ('GGATCCATGGGCGCGTCGGATCTCGA', 'GAATTCCTAGGATAAAGGACAACAAA')
# files\84.fasta ('CTCGAGATGAGGCTATCTGATGATTC', 'GAATTCTCAAACATACGGCCAGCGAT')
# files\85.fasta ('GAATTCATGGCCCCTAAGTTCAGGGA', 'CTCGAGTCAAAATATAGACTGCAGTA')
# files\86.fasta ('GAATTCATGTATGCTGGGATAACATT', 'TCTAGATCAGGATTCGCACATCATCA')
# files\87.fasta ('AAGCTTATGCAACTGCTTGGTCGAAC', 'GAATTCCTACAGACGTTCTCGATCAC')
# files\88.fasta ('AAGCTTATGATGGTGAACGGGCGATC', 'CTCGAGCTAAAGGTAGAGGAGTAACA')
# files\89.fasta ('CTGCAGATGCAAAACGAGTGGAAGTG', 'TCTAGATCAATCATAGAAGTCTGGCT')
# files\90.fasta ('CTGCAGATGTTAATATATGTACAGAT', 'GAATTCTTACGTCTTACCGAGGCAGA')
# files\91.fasta ('GAATTCATGATCAACGACTTTTCCAC', 'AAGCTTTCACGCTCGTTTCAGTAGAT')
# files\92.fasta ('AAGCTTATGGGTAACCGCGGGTTCTG', 'GAATTCTCATGACTGCTGATGCCTCT')
# files\93.fasta ('GGATCCATGTATGCTGATCGTCTGAT', 'CTGCAGCTATATGCAGCATGCGTATT')
# files\94.fasta ('CTGCAGATGGGTGATTTTCAAATAGA', 'GGATCCTTAAGACGTGACCCTTATAC')
# files\95.fasta ('GGATCCATGAGTATAACGTCGCGCCC', 'AAGCTTTTAAAACGGGTCGCGTATAC')
# files\96.fasta ('TCTAGAATGTGGGTGCATAAGTACTA', 'AAGCTTCTACTCACTCTGACATCGAA')
# files\97.fasta ('TCTAGAATGAGCTTTGCCGGGTGGTT', 'GAATTCCTATGTGAGAAGAGAGTAGC')
# files\98.fasta ('AAGCTTATGTGTCCAGCGGATTCCCA', 'GAATTCTCAACTCGGGACTAGCAACA')
# files\99.fasta ('GGATCCATGTTAATAAGTAAACGATG', 'AAGCTTCTATGGATCTTTCGGGCATG')
# files\100.fasta ('AAGCTTATGCGAATATCTGGTAAAGT', 'CTCGAGTTAGAACATCAAAACGAGTA')
# done
